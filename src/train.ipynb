# %%
import opendatasets as od
od.download('https://www.kaggle.com/datasets/arevel/chess-games')
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username:Your Kaggle Key:Dataset URL: https://www.kaggle.com/datasets/arevel/chess-games
# Downloading chess-games.zip to ./chess-games
# 100%|██████████| 1.45G/1.45G [00:01<00:00, 838MB/s]

# %%
import re

import numpy as np
import pandas as pd

import preprocessing
from constants import PIECE_TYPES

import torch
from torch.utils.data import TensorDataset, DataLoader

# %%
def adapt_moves(game_history):
    no_numbers = re.sub(r'\d+\.', '', game_history)

    moves = [move.strip() for move in no_numbers.split() if move.strip()]
    moves.pop() # remove winner / loser

    return ' '.join(moves)

# %%
FILE_PATH = '../data/chess_games.csv'
MOVES_COLUMN = 'AN'
ELO_COLUMN = 'WhiteElo'
RESULT_COLUMN = 'Result'

ELO_THRESHOLD = 1600
WHITE_WIN = '1-0'

BATCH_SIZE = 32
SHUFFLE = True

# %%
def load_dataloaders(original_headers, limit=1_000_000, offset=0):
    data_df = pd.read_csv(FILE_PATH, nrows=limit, skiprows=offset+1, names=original_headers)

    piece_selection_X = []
    piece_selection_y = []

    move_selection = {}

    for index, raw in enumerate(data_df[MOVES_COLUMN]):
        if data_df[ELO_COLUMN][index] <= ELO_THRESHOLD:
          continue

        if data_df[RESULT_COLUMN][index] != WHITE_WIN:
          continue

        try:
            (current_ps_X, current_ps_y, current_ms) = preprocessing.preprocess_game(adapt_moves(raw))

            print(f"Loaded & preprocessed game from the dataset {index}/{len(data_df)}")

            piece_selection_X.append(current_ps_X)
            piece_selection_y.append(current_ps_y)

            move_selection = {
                k: move_selection.get(k, []) + current_ms.get(k, []) for k in set(move_selection) | set(current_ms)
            }
        except Exception as ex:
            continue

    ps_dataloader = DataLoader(
        TensorDataset(
            torch.from_numpy(np.concatenate(piece_selection_X, axis=0)).float(),
            torch.from_numpy(np.concatenate(piece_selection_y, axis=0)).long(),
        ),
        batch_size=BATCH_SIZE,
        shuffle=SHUFFLE,
    )

    ms_dataloaders = []

    for piece_type in PIECE_TYPES:
        index = PIECE_TYPES[piece_type]
        ms_X, ms_y = zip(*move_selection[index])
        ms_dataloaders.append(
            DataLoader(
                TensorDataset(
                    torch.tensor(ms_X, dtype=torch.float32),
                    torch.tensor(ms_y, dtype=torch.long),
                ),
                batch_size=BATCH_SIZE,
                shuffle=SHUFFLE,
            )
        )

    return ps_dataloader, ms_dataloaders

# %%
def train(dataloader, model, device):
    model.train()
    total_loss = 0

    for batch_idx, (X, y) in enumerate(dataloader):
        size = len(dataloader.dataset)
        X, y = X.to(device), y.to(device)

        prediction = model(X)
        loss = model.loss_fn(prediction, y)
        total_loss += loss

        loss.backward()
        model.optimizer.step()
        model.optimizer.zero_grad()

        if batch_idx % 100 == 0:
            loss, current = loss.item(), (batch_idx + 1) * len(X)
            print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")

def test(dataloader, model, device):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)

    model.eval()
    test_loss, correct = 0, 0

    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X)
            test_loss += model.loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()

    test_loss /= num_batches
    correct /= size

    print(f"Test Error: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f} \n")

# %%
from models import PieceSelector, MoveSelector

# %%
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")

# %%
training_limit = 2_000_000
dataset_batch_step = 10_000

piece_selector = PieceSelector().to(device)
move_selectors = []

for piece_type in PIECE_TYPES:
    move_selectors.append(MoveSelector().to(device))

header_df = pd.read_csv(FILE_PATH, nrows=0)
original_headers = list(header_df.columns)

epochs = 15

for epoch in range(epochs):
  print(f"Epoch: {epoch+1}/{epochs}")

  for dataset_batch in range(0, training_limit, dataset_batch_step):
    print(f"Processing dataset batch: {dataset_batch} / {training_limit}")
    ps_dataloader, ms_dataloaders = load_dataloaders(original_headers, dataset_batch, dataset_batch)

    print("Training piece selector model")
    train(ps_dataloader, piece_selector, device)
    test(ps_dataloader, piece_selector, device)

    for piece_type in PIECE_TYPES:
      print(f"Training move selector model for {piece_type}")
      index = PIECE_TYPES[piece_type]
      move_selector = move_selectors[index]
      train(ms_dataloaders[index], move_selector, device)
      test(ms_dataloaders[index], move_selector, device)

  torch.save(piece_selector.state_dict(), 'model/piece-selector.pth')

  for piece_type in PIECE_TYPES:
    index = PIECE_TYPES[piece_type]
    move_selector = move_selectors[index]
    torch.save(move_selector.state_dict(), f'model/{piece_type}.pth')
# Out:
# Epoch: 1/15
# Processing dataset batch: 0 / 2000000
# Loaded & preprocessed game from the dataset 0/5000
# Loaded & preprocessed game from the dataset 2/5000
# Loaded & preprocessed game from the dataset 3/5000
# Loaded & preprocessed game from the dataset 7/5000
# Loaded & preprocessed game from the dataset 9/5000
# Loaded & preprocessed game from the dataset 11/5000
# Loaded & preprocessed game from the dataset 12/5000
# Loaded & preprocessed game from the dataset 13/5000
# Loaded & preprocessed game from the dataset 16/5000
# Loaded & preprocessed game from the dataset 17/5000
# Loaded & preprocessed game from the dataset 19/5000
# Loaded & preprocessed game from the dataset 20/5000
# Loaded & preprocessed game from the dataset 22/5000
# Loaded & preprocessed game from the dataset 25/5000
# Loaded & preprocessed game from the dataset 27/5000
# Loaded & preprocessed game from the dataset 28/5000
# Loaded & preprocessed game from the dataset 29/5000
# Loaded & preprocessed game from the dataset 38/5000
# Loaded & preprocessed game from the dataset 39/5000
# Loaded & preprocessed game from the dataset 42/5000
# Loaded & preprocessed game from the dataset 45/5000
# Loaded & preprocessed game from the dataset 48/5000
# Loaded & preprocessed game from the dataset 59/5000
# Loaded & preprocessed game from the dataset 66/5000
# Loaded & preprocessed game from the dataset 67/5000
# Loaded & preprocessed game from the dataset 68/5000
# Loaded & preprocessed game from the dataset 71/5000
# Loaded & preprocessed game from the dataset 72/5000
# Loaded & preprocessed game from the dataset 85/5000
# Loaded & preprocessed game from the dataset 91/5000
# Loaded & preprocessed game from the dataset 94/5000
# Loaded & preprocessed game from the dataset 97/5000
# Loaded & preprocessed game from the dataset 104/5000
# Loaded & preprocessed game from the dataset 106/5000
# Loaded & preprocessed game from the dataset 108/5000
# Loaded & preprocessed game from the dataset 112/5000
# Loaded & preprocessed game from the dataset 114/5000
# Loaded & preprocessed game from the dataset 116/5000
# Loaded & preprocessed game from the dataset 117/5000
# Loaded & preprocessed game from the dataset 121/5000
# Loaded & preprocessed game from the dataset 123/5000
# Loaded & preprocessed game from the dataset 141/5000
# Loaded & preprocessed game from the dataset 142/5000
# Loaded & preprocessed game from the dataset 150/5000
# Loaded & preprocessed game from the dataset 151/5000
# Loaded & preprocessed game from the dataset 153/5000
# Loaded & preprocessed game from the dataset 155/5000
# Loaded & preprocessed game from the dataset 156/5000
# Loaded & preprocessed game from the dataset 158/5000
# Loaded & preprocessed game from the dataset 160/5000
# Loaded & preprocessed game from the dataset 165/5000
# Loaded & preprocessed game from the dataset 167/5000
# Loaded & preprocessed game from the dataset 168/5000
# Loaded & preprocessed game from the dataset 169/5000
# Loaded & preprocessed game from the dataset 171/5000
# Loaded & preprocessed game from the dataset 172/5000
# Loaded & preprocessed game from the dataset 178/5000
# Loaded & preprocessed game from the dataset 179/5000
# Loaded & preprocessed game from the dataset 182/5000
# Loaded & preprocessed game from the dataset 183/5000
# Loaded & preprocessed game from the dataset 188/5000
# Loaded & preprocessed game from the dataset 192/5000
# Loaded & preprocessed game from the dataset 195/5000
# Loaded & preprocessed game from the dataset 201/5000
# Loaded & preprocessed game from the dataset 202/5000
# Loaded & preprocessed game from the dataset 203/5000
# Loaded & preprocessed game from the dataset 204/5000
# Loaded & preprocessed game from the dataset 208/5000
# Loaded & preprocessed game from the dataset 210/5000
# Loaded & preprocessed game from the dataset 219/5000
# Loaded & preprocessed game from the dataset 220/5000
# Loaded & preprocessed game from the dataset 221/5000
# Loaded & preprocessed game from the dataset 222/5000
# Loaded & preprocessed game from the dataset 223/5000
# Loaded & preprocessed game from the dataset 224/5000
# Loaded & preprocessed game from the dataset 226/5000
# Loaded & preprocessed game from the dataset 228/5000
# Loaded & preprocessed game from the dataset 229/5000
# Loaded & preprocessed game from the dataset 230/5000
# Loaded & preprocessed game from the dataset 233/5000
# Loaded & preprocessed game from the dataset 234/5000
# Loaded & preprocessed game from the dataset 236/5000
# Loaded & preprocessed game from the dataset 239/5000
# Loaded & preprocessed game from the dataset 241/5000
# Loaded & preprocessed game from the dataset 243/5000
# Loaded & preprocessed game from the dataset 247/5000
# Loaded & preprocessed game from the dataset 248/5000
# Loaded & preprocessed game from the dataset 249/5000
# Loaded & preprocessed game from the dataset 252/5000
# Loaded & preprocessed game from the dataset 253/5000
# Loaded & preprocessed game from the dataset 255/5000
# Loaded & preprocessed game from the dataset 257/5000
# Loaded & preprocessed game from the dataset 259/5000
# Loaded & preprocessed game from the dataset 261/5000
# Loaded & preprocessed game from the dataset 270/5000
# Loaded & preprocessed game from the dataset 272/5000
# Loaded & preprocessed game from the dataset 277/5000
# Loaded & preprocessed game from the dataset 280/5000
# Loaded & preprocessed game from the dataset 282/5000
# Loaded & preprocessed game from the dataset 287/5000
# Loaded & preprocessed game from the dataset 290/5000
# Loaded & preprocessed game from the dataset 293/5000
# Loaded & preprocessed game from the dataset 303/5000
# Loaded & preprocessed game from the dataset 304/5000
# Loaded & preprocessed game from the dataset 305/5000
# Loaded & preprocessed game from the dataset 307/5000
# Loaded & preprocessed game from the dataset 311/5000
# Loaded & preprocessed game from the dataset 312/5000
# Loaded & preprocessed game from the dataset 313/5000
# Loaded & preprocessed game from the dataset 323/5000
# Loaded & preprocessed game from the dataset 324/5000
# Loaded & preprocessed game from the dataset 329/5000
# Loaded & preprocessed game from the dataset 332/5000
# Loaded & preprocessed game from the dataset 336/5000
# Loaded & preprocessed game from the dataset 340/5000
# Loaded & preprocessed game from the dataset 341/5000
# Loaded & preprocessed game from the dataset 342/5000
# Loaded & preprocessed game from the dataset 344/5000
# Loaded & preprocessed game from the dataset 345/5000
# Loaded & preprocessed game from the dataset 347/5000
# Loaded & preprocessed game from the dataset 348/5000
# Loaded & preprocessed game from the dataset 356/5000
# Loaded & preprocessed game from the dataset 358/5000
# Loaded & preprocessed game from the dataset 362/5000
# Loaded & preprocessed game from the dataset 365/5000
# Loaded & preprocessed game from the dataset 373/5000
# Loaded & preprocessed game from the dataset 374/5000
# Loaded & preprocessed game from the dataset 378/5000
# Loaded & preprocessed game from the dataset 379/5000
# Loaded & preprocessed game from the dataset 383/5000
# Loaded & preprocessed game from the dataset 384/5000
# Loaded & preprocessed game from the dataset 385/5000
# Loaded & preprocessed game from the dataset 386/5000
# Loaded & preprocessed game from the dataset 387/5000
# Loaded & preprocessed game from the dataset 389/5000
# Loaded & preprocessed game from the dataset 391/5000
# Loaded & preprocessed game from the dataset 395/5000
# Loaded & preprocessed game from the dataset 410/5000
# Loaded & preprocessed game from the dataset 411/5000
# Loaded & preprocessed game from the dataset 412/5000
# Loaded & preprocessed game from the dataset 415/5000
# Loaded & preprocessed game from the dataset 418/5000
# Loaded & preprocessed game from the dataset 421/5000
# Loaded & preprocessed game from the dataset 426/5000
# Loaded & preprocessed game from the dataset 429/5000
# Loaded & preprocessed game from the dataset 430/5000
# Loaded & preprocessed game from the dataset 431/5000
# Loaded & preprocessed game from the dataset 437/5000
# Loaded & preprocessed game from the dataset 438/5000
# Loaded & preprocessed game from the dataset 440/5000
# Loaded & preprocessed game from the dataset 442/5000
# Loaded & preprocessed game from the dataset 448/5000
# Loaded & preprocessed game from the dataset 450/5000
# Loaded & preprocessed game from the dataset 453/5000
# Loaded & preprocessed game from the dataset 454/5000
# Loaded & preprocessed game from the dataset 458/5000
# Loaded & preprocessed game from the dataset 461/5000
# Loaded & preprocessed game from the dataset 463/5000
# Loaded & preprocessed game from the dataset 468/5000
# Loaded & preprocessed game from the dataset 473/5000
# Loaded & preprocessed game from the dataset 474/5000
# Loaded & preprocessed game from the dataset 476/5000
# Loaded & preprocessed game from the dataset 481/5000
# Loaded & preprocessed game from the dataset 484/5000
# Loaded & preprocessed game from the dataset 485/5000
# Loaded & preprocessed game from the dataset 486/5000
# Loaded & preprocessed game from the dataset 488/5000
# Loaded & preprocessed game from the dataset 495/5000
# Loaded & preprocessed game from the dataset 498/5000
# Loaded & preprocessed game from the dataset 503/5000
# Loaded & preprocessed game from the dataset 504/5000
# Loaded & preprocessed game from the dataset 507/5000
# Loaded & preprocessed game from the dataset 509/5000
# Loaded & preprocessed game from the dataset 510/5000
# Loaded & preprocessed game from the dataset 519/5000
# Loaded & preprocessed game from the dataset 520/5000
# Loaded & preprocessed game from the dataset 533/5000
# Loaded & preprocessed game from the dataset 537/5000
# Loaded & preprocessed game from the dataset 539/5000
# Loaded & preprocessed game from the dataset 541/5000
# Loaded & preprocessed game from the dataset 544/5000
# Loaded & preprocessed game from the dataset 547/5000
# Loaded & preprocessed game from the dataset 550/5000
# Loaded & preprocessed game from the dataset 560/5000
# Loaded & preprocessed game from the dataset 563/5000
# Loaded & preprocessed game from the dataset 565/5000
# Loaded & preprocessed game from the dataset 567/5000
# Loaded & preprocessed game from the dataset 569/5000
# Loaded & preprocessed game from the dataset 576/5000
# Loaded & preprocessed game from the dataset 577/5000
# Loaded & preprocessed game from the dataset 578/5000
# Loaded & preprocessed game from the dataset 581/5000
# Loaded & preprocessed game from the dataset 582/5000
# Loaded & preprocessed game from the dataset 583/5000
# Loaded & preprocessed game from the dataset 584/5000
# Loaded & preprocessed game from the dataset 585/5000
# Loaded & preprocessed game from the dataset 587/5000
# Loaded & preprocessed game from the dataset 588/5000
# Loaded & preprocessed game from the dataset 593/5000
# Loaded & preprocessed game from the dataset 600/5000
# Loaded & preprocessed game from the dataset 602/5000
# Loaded & preprocessed game from the dataset 606/5000
# Loaded & preprocessed game from the dataset 607/5000
# Loaded & preprocessed game from the dataset 609/5000
# Loaded & preprocessed game from the dataset 611/5000
# Loaded & preprocessed game from the dataset 614/5000
# Loaded & preprocessed game from the dataset 616/5000
# Loaded & preprocessed game from the dataset 617/5000
# Loaded & preprocessed game from the dataset 620/5000
# Loaded & preprocessed game from the dataset 621/5000
# Loaded & preprocessed game from the dataset 627/5000
# Loaded & preprocessed game from the dataset 630/5000
# Loaded & preprocessed game from the dataset 645/5000
# Loaded & preprocessed game from the dataset 648/5000
# Loaded & preprocessed game from the dataset 649/5000
# Loaded & preprocessed game from the dataset 650/5000
# Loaded & preprocessed game from the dataset 651/5000
# Loaded & preprocessed game from the dataset 653/5000
# Loaded & preprocessed game from the dataset 658/5000
# Loaded & preprocessed game from the dataset 659/5000
# Loaded & preprocessed game from the dataset 661/5000
# Loaded & preprocessed game from the dataset 663/5000
# Loaded & preprocessed game from the dataset 664/5000
# Loaded & preprocessed game from the dataset 673/5000
# Loaded & preprocessed game from the dataset 675/5000
# Loaded & preprocessed game from the dataset 678/5000
# Loaded & preprocessed game from the dataset 679/5000
# Loaded & preprocessed game from the dataset 680/5000
# Loaded & preprocessed game from the dataset 681/5000
# Loaded & preprocessed game from the dataset 682/5000
# Loaded & preprocessed game from the dataset 684/5000
# Loaded & preprocessed game from the dataset 685/5000
# Loaded & preprocessed game from the dataset 689/5000
# Loaded & preprocessed game from the dataset 690/5000
# Loaded & preprocessed game from the dataset 694/5000
# Loaded & preprocessed game from the dataset 696/5000
# Loaded & preprocessed game from the dataset 698/5000
# Loaded & preprocessed game from the dataset 700/5000
# Loaded & preprocessed game from the dataset 704/5000
# Loaded & preprocessed game from the dataset 708/5000
# Loaded & preprocessed game from the dataset 709/5000
# Loaded & preprocessed game from the dataset 710/5000
# Loaded & preprocessed game from the dataset 715/5000
# Loaded & preprocessed game from the dataset 716/5000
# Loaded & preprocessed game from the dataset 717/5000
# Loaded & preprocessed game from the dataset 718/5000
# Loaded & preprocessed game from the dataset 719/5000
# Loaded & preprocessed game from the dataset 722/5000
# Loaded & preprocessed game from the dataset 723/5000
# Loaded & preprocessed game from the dataset 729/5000
# Loaded & preprocessed game from the dataset 730/5000
# Loaded & preprocessed game from the dataset 733/5000
# Loaded & preprocessed game from the dataset 734/5000
# Loaded & preprocessed game from the dataset 737/5000
# Loaded & preprocessed game from the dataset 740/5000
# Loaded & preprocessed game from the dataset 742/5000
# Loaded & preprocessed game from the dataset 747/5000
# Loaded & preprocessed game from the dataset 764/5000
# Loaded & preprocessed game from the dataset 774/5000
# Loaded & preprocessed game from the dataset 777/5000
# Loaded & preprocessed game from the dataset 779/5000
# Loaded & preprocessed game from the dataset 780/5000
# Loaded & preprocessed game from the dataset 781/5000
# Loaded & preprocessed game from the dataset 788/5000
# Loaded & preprocessed game from the dataset 789/5000
# Loaded & preprocessed game from the dataset 794/5000
# Loaded & preprocessed game from the dataset 799/5000
# Loaded & preprocessed game from the dataset 806/5000
# Loaded & preprocessed game from the dataset 807/5000
# Loaded & preprocessed game from the dataset 813/5000
# Loaded & preprocessed game from the dataset 815/5000
# Loaded & preprocessed game from the dataset 818/5000
# Loaded & preprocessed game from the dataset 820/5000
# Loaded & preprocessed game from the dataset 833/5000
# Loaded & preprocessed game from the dataset 834/5000
# Loaded & preprocessed game from the dataset 841/5000
# Loaded & preprocessed game from the dataset 844/5000
# Loaded & preprocessed game from the dataset 846/5000
# Loaded & preprocessed game from the dataset 847/5000
# Loaded & preprocessed game from the dataset 851/5000
# Loaded & preprocessed game from the dataset 852/5000
# Loaded & preprocessed game from the dataset 858/5000
# Loaded & preprocessed game from the dataset 860/5000
# Loaded & preprocessed game from the dataset 861/5000
# Loaded & preprocessed game from the dataset 862/5000
# Loaded & preprocessed game from the dataset 865/5000
# Loaded & preprocessed game from the dataset 866/5000
# Loaded & preprocessed game from the dataset 868/5000
# Loaded & preprocessed game from the dataset 872/5000
# Loaded & preprocessed game from the dataset 873/5000
# Loaded & preprocessed game from the dataset 880/5000
# Loaded & preprocessed game from the dataset 885/5000
# Loaded & preprocessed game from the dataset 886/5000
# Loaded & preprocessed game from the dataset 892/5000
# Loaded & preprocessed game from the dataset 893/5000
# Loaded & preprocessed game from the dataset 900/5000
# Loaded & preprocessed game from the dataset 909/5000
# Loaded & preprocessed game from the dataset 910/5000
# Loaded & preprocessed game from the dataset 914/5000
# Loaded & preprocessed game from the dataset 915/5000
# Loaded & preprocessed game from the dataset 916/5000
# Loaded & preprocessed game from the dataset 917/5000
# Loaded & preprocessed game from the dataset 922/5000
# Loaded & preprocessed game from the dataset 923/5000
# Loaded & preprocessed game from the dataset 930/5000
# Loaded & preprocessed game from the dataset 931/5000
# Loaded & preprocessed game from the dataset 932/5000
# Loaded & preprocessed game from the dataset 934/5000
# Loaded & preprocessed game from the dataset 936/5000
# Loaded & preprocessed game from the dataset 938/5000
# Loaded & preprocessed game from the dataset 942/5000
# Loaded & preprocessed game from the dataset 947/5000
# Loaded & preprocessed game from the dataset 949/5000
# Loaded & preprocessed game from the dataset 950/5000
# Loaded & preprocessed game from the dataset 957/5000
# Loaded & preprocessed game from the dataset 958/5000
# Loaded & preprocessed game from the dataset 959/5000
# Loaded & preprocessed game from the dataset 972/5000
# Loaded & preprocessed game from the dataset 976/5000
# Loaded & preprocessed game from the dataset 978/5000
# Loaded & preprocessed game from the dataset 981/5000
# Loaded & preprocessed game from the dataset 991/5000
# Loaded & preprocessed game from the dataset 993/5000
# Loaded & preprocessed game from the dataset 1006/5000
# Loaded & preprocessed game from the dataset 1007/5000
# Loaded & preprocessed game from the dataset 1012/5000
# Loaded & preprocessed game from the dataset 1015/5000
# Loaded & preprocessed game from the dataset 1016/5000
# Loaded & preprocessed game from the dataset 1017/5000
# Loaded & preprocessed game from the dataset 1019/5000
# Loaded & preprocessed game from the dataset 1021/5000
# Loaded & preprocessed game from the dataset 1027/5000
# Loaded & preprocessed game from the dataset 1028/5000
# Loaded & preprocessed game from the dataset 1029/5000
# Loaded & preprocessed game from the dataset 1034/5000
# Loaded & preprocessed game from the dataset 1035/5000
# Loaded & preprocessed game from the dataset 1042/5000
# Loaded & preprocessed game from the dataset 1043/5000
# Loaded & preprocessed game from the dataset 1049/5000
# Loaded & preprocessed game from the dataset 1050/5000
# Loaded & preprocessed game from the dataset 1051/5000
# Loaded & preprocessed game from the dataset 1057/5000
# Loaded & preprocessed game from the dataset 1072/5000
# Loaded & preprocessed game from the dataset 1073/5000
# Loaded & preprocessed game from the dataset 1074/5000
# Loaded & preprocessed game from the dataset 1079/5000
# Loaded & preprocessed game from the dataset 1080/5000
# Loaded & preprocessed game from the dataset 1087/5000
# Loaded & preprocessed game from the dataset 1089/5000
# Loaded & preprocessed game from the dataset 1095/5000
# Loaded & preprocessed game from the dataset 1099/5000
# Loaded & preprocessed game from the dataset 1102/5000
# Loaded & preprocessed game from the dataset 1105/5000
# Loaded & preprocessed game from the dataset 1115/5000
# Loaded & preprocessed game from the dataset 1116/5000
# Loaded & preprocessed game from the dataset 1118/5000
# Loaded & preprocessed game from the dataset 1120/5000
# Loaded & preprocessed game from the dataset 1128/5000
# Loaded & preprocessed game from the dataset 1136/5000
# Loaded & preprocessed game from the dataset 1143/5000
# Loaded & preprocessed game from the dataset 1144/5000
# Loaded & preprocessed game from the dataset 1150/5000
# Loaded & preprocessed game from the dataset 1151/5000
# Loaded & preprocessed game from the dataset 1152/5000
# Loaded & preprocessed game from the dataset 1159/5000
# Loaded & preprocessed game from the dataset 1160/5000
# Loaded & preprocessed game from the dataset 1161/5000
# Loaded & preprocessed game from the dataset 1162/5000
# Loaded & preprocessed game from the dataset 1163/5000
# Loaded & preprocessed game from the dataset 1164/5000
# Loaded & preprocessed game from the dataset 1165/5000
# Loaded & preprocessed game from the dataset 1169/5000
# Loaded & preprocessed game from the dataset 1173/5000
# Loaded & preprocessed game from the dataset 1176/5000
# Loaded & preprocessed game from the dataset 1181/5000
# Loaded & preprocessed game from the dataset 1184/5000
# Loaded & preprocessed game from the dataset 1186/5000
# Loaded & preprocessed game from the dataset 1190/5000
# Loaded & preprocessed game from the dataset 1193/5000
# Loaded & preprocessed game from the dataset 1199/5000
# Loaded & preprocessed game from the dataset 1203/5000
# Loaded & preprocessed game from the dataset 1214/5000
# Loaded & preprocessed game from the dataset 1215/5000
# Loaded & preprocessed game from the dataset 1217/5000
# Loaded & preprocessed game from the dataset 1223/5000
# Loaded & preprocessed game from the dataset 1224/5000
# Loaded & preprocessed game from the dataset 1225/5000
# Loaded & preprocessed game from the dataset 1229/5000
# Loaded & preprocessed game from the dataset 1231/5000
# Loaded & preprocessed game from the dataset 1235/5000
# Loaded & preprocessed game from the dataset 1237/5000
# Loaded & preprocessed game from the dataset 1239/5000
# Loaded & preprocessed game from the dataset 1241/5000
# Loaded & preprocessed game from the dataset 1244/5000
# Loaded & preprocessed game from the dataset 1246/5000
# Loaded & preprocessed game from the dataset 1247/5000
# Loaded & preprocessed game from the dataset 1248/5000
# Loaded & preprocessed game from the dataset 1250/5000
# Loaded & preprocessed game from the dataset 1251/5000
# Loaded & preprocessed game from the dataset 1255/5000
# Loaded & preprocessed game from the dataset 1257/5000
# Loaded & preprocessed game from the dataset 1268/5000
# Loaded & preprocessed game from the dataset 1270/5000
# Loaded & preprocessed game from the dataset 1272/5000
# Loaded & preprocessed game from the dataset 1273/5000
# Loaded & preprocessed game from the dataset 1275/5000
# Loaded & preprocessed game from the dataset 1280/5000
# Loaded & preprocessed game from the dataset 1281/5000
# Loaded & preprocessed game from the dataset 1282/5000
# Loaded & preprocessed game from the dataset 1283/5000
# Loaded & preprocessed game from the dataset 1284/5000
# Loaded & preprocessed game from the dataset 1287/5000
# Loaded & preprocessed game from the dataset 1291/5000
# Loaded & preprocessed game from the dataset 1294/5000
# Loaded & preprocessed game from the dataset 1295/5000
# Loaded & preprocessed game from the dataset 1298/5000
# Loaded & preprocessed game from the dataset 1299/5000
# Loaded & preprocessed game from the dataset 1300/5000
# Loaded & preprocessed game from the dataset 1305/5000
# Loaded & preprocessed game from the dataset 1320/5000
# Loaded & preprocessed game from the dataset 1325/5000
# Loaded & preprocessed game from the dataset 1328/5000
# Loaded & preprocessed game from the dataset 1329/5000
# Loaded & preprocessed game from the dataset 1333/5000
# Loaded & preprocessed game from the dataset 1335/5000
# Loaded & preprocessed game from the dataset 1340/5000
# Loaded & preprocessed game from the dataset 1343/5000
# Loaded & preprocessed game from the dataset 1344/5000
# Loaded & preprocessed game from the dataset 1350/5000
# Loaded & preprocessed game from the dataset 1353/5000
# Loaded & preprocessed game from the dataset 1356/5000
# Loaded & preprocessed game from the dataset 1358/5000
# Loaded & preprocessed game from the dataset 1362/5000
# Loaded & preprocessed game from the dataset 1365/5000
# Loaded & preprocessed game from the dataset 1366/5000
# Loaded & preprocessed game from the dataset 1368/5000
# Loaded & preprocessed game from the dataset 1370/5000
# Loaded & preprocessed game from the dataset 1377/5000
# Loaded & preprocessed game from the dataset 1380/5000
# Loaded & preprocessed game from the dataset 1383/5000
# Loaded & preprocessed game from the dataset 1385/5000
# Loaded & preprocessed game from the dataset 1388/5000
# Loaded & preprocessed game from the dataset 1390/5000
# Loaded & preprocessed game from the dataset 1393/5000
# Loaded & preprocessed game from the dataset 1394/5000
# Loaded & preprocessed game from the dataset 1398/5000
# Loaded & preprocessed game from the dataset 1410/5000
# Loaded & preprocessed game from the dataset 1412/5000
# Loaded & preprocessed game from the dataset 1414/5000
# Loaded & preprocessed game from the dataset 1415/5000
# Loaded & preprocessed game from the dataset 1417/5000
# Loaded & preprocessed game from the dataset 1422/5000
# Loaded & preprocessed game from the dataset 1423/5000
# Loaded & preprocessed game from the dataset 1426/5000
# Loaded & preprocessed game from the dataset 1431/5000
# Loaded & preprocessed game from the dataset 1438/5000
# Loaded & preprocessed game from the dataset 1440/5000
# Loaded & preprocessed game from the dataset 1442/5000
# Loaded & preprocessed game from the dataset 1447/5000
# Loaded & preprocessed game from the dataset 1448/5000
# Loaded & preprocessed game from the dataset 1449/5000
# Loaded & preprocessed game from the dataset 1450/5000
# Loaded & preprocessed game from the dataset 1451/5000
# Loaded & preprocessed game from the dataset 1452/5000
# Loaded & preprocessed game from the dataset 1453/5000
# Loaded & preprocessed game from the dataset 1456/5000
# Loaded & preprocessed game from the dataset 1457/5000
# Loaded & preprocessed game from the dataset 1460/5000
# Loaded & preprocessed game from the dataset 1462/5000
# Loaded & preprocessed game from the dataset 1463/5000
# Loaded & preprocessed game from the dataset 1464/5000
# Loaded & preprocessed game from the dataset 1465/5000
# Loaded & preprocessed game from the dataset 1467/5000
# Loaded & preprocessed game from the dataset 1473/5000
# Loaded & preprocessed game from the dataset 1474/5000
# Loaded & preprocessed game from the dataset 1475/5000
# Loaded & preprocessed game from the dataset 1480/5000
# Loaded & preprocessed game from the dataset 1485/5000
# Loaded & preprocessed game from the dataset 1492/5000
# Loaded & preprocessed game from the dataset 1493/5000
# Loaded & preprocessed game from the dataset 1496/5000
# Loaded & preprocessed game from the dataset 1499/5000
# Loaded & preprocessed game from the dataset 1500/5000
# Loaded & preprocessed game from the dataset 1502/5000
# Loaded & preprocessed game from the dataset 1504/5000
# Loaded & preprocessed game from the dataset 1508/5000
# Loaded & preprocessed game from the dataset 1514/5000
# Loaded & preprocessed game from the dataset 1517/5000
# Loaded & preprocessed game from the dataset 1519/5000
# Loaded & preprocessed game from the dataset 1520/5000
# Loaded & preprocessed game from the dataset 1523/5000
# Loaded & preprocessed game from the dataset 1530/5000
# Loaded & preprocessed game from the dataset 1533/5000
# Loaded & preprocessed game from the dataset 1538/5000
# Loaded & preprocessed game from the dataset 1539/5000
# Loaded & preprocessed game from the dataset 1540/5000
# Loaded & preprocessed game from the dataset 1541/5000
# Loaded & preprocessed game from the dataset 1545/5000
# Loaded & preprocessed game from the dataset 1550/5000
# Loaded & preprocessed game from the dataset 1553/5000
# Loaded & preprocessed game from the dataset 1556/5000
# Loaded & preprocessed game from the dataset 1557/5000
# Loaded & preprocessed game from the dataset 1565/5000
# Loaded & preprocessed game from the dataset 1567/5000
# Loaded & preprocessed game from the dataset 1571/5000
# Loaded & preprocessed game from the dataset 1572/5000
# Loaded & preprocessed game from the dataset 1573/5000
# Loaded & preprocessed game from the dataset 1577/5000
# Loaded & preprocessed game from the dataset 1591/5000
# Loaded & preprocessed game from the dataset 1593/5000
# Loaded & preprocessed game from the dataset 1595/5000
# Loaded & preprocessed game from the dataset 1596/5000
# Loaded & preprocessed game from the dataset 1597/5000
# Loaded & preprocessed game from the dataset 1601/5000
# Loaded & preprocessed game from the dataset 1603/5000
# Loaded & preprocessed game from the dataset 1604/5000
# Loaded & preprocessed game from the dataset 1608/5000
# Loaded & preprocessed game from the dataset 1609/5000
# Loaded & preprocessed game from the dataset 1610/5000
# Loaded & preprocessed game from the dataset 1611/5000
# Loaded & preprocessed game from the dataset 1612/5000
# Loaded & preprocessed game from the dataset 1624/5000
# Loaded & preprocessed game from the dataset 1629/5000
# Loaded & preprocessed game from the dataset 1632/5000
# Loaded & preprocessed game from the dataset 1642/5000
# Loaded & preprocessed game from the dataset 1648/5000
# Loaded & preprocessed game from the dataset 1649/5000
# Loaded & preprocessed game from the dataset 1650/5000
# Loaded & preprocessed game from the dataset 1651/5000
# Loaded & preprocessed game from the dataset 1658/5000
# Loaded & preprocessed game from the dataset 1659/5000
# Loaded & preprocessed game from the dataset 1669/5000
# Loaded & preprocessed game from the dataset 1670/5000
# Loaded & preprocessed game from the dataset 1671/5000
# Loaded & preprocessed game from the dataset 1674/5000
# Loaded & preprocessed game from the dataset 1682/5000
# Loaded & preprocessed game from the dataset 1683/5000
# Loaded & preprocessed game from the dataset 1686/5000
# Loaded & preprocessed game from the dataset 1687/5000
# Loaded & preprocessed game from the dataset 1688/5000
# Loaded & preprocessed game from the dataset 1691/5000
# Loaded & preprocessed game from the dataset 1692/5000
# Loaded & preprocessed game from the dataset 1693/5000
# Loaded & preprocessed game from the dataset 1694/5000
# Loaded & preprocessed game from the dataset 1697/5000
# Loaded & preprocessed game from the dataset 1698/5000
# Loaded & preprocessed game from the dataset 1700/5000
# Loaded & preprocessed game from the dataset 1707/5000
# Loaded & preprocessed game from the dataset 1708/5000
# Loaded & preprocessed game from the dataset 1712/5000
# Loaded & preprocessed game from the dataset 1713/5000
# Loaded & preprocessed game from the dataset 1720/5000
# Loaded & preprocessed game from the dataset 1721/5000
# Loaded & preprocessed game from the dataset 1722/5000
# Loaded & preprocessed game from the dataset 1726/5000
# Loaded & preprocessed game from the dataset 1727/5000
# Loaded & preprocessed game from the dataset 1737/5000
# Loaded & preprocessed game from the dataset 1741/5000
# Loaded & preprocessed game from the dataset 1744/5000
# Loaded & preprocessed game from the dataset 1745/5000
# Loaded & preprocessed game from the dataset 1751/5000
# Loaded & preprocessed game from the dataset 1757/5000
# Loaded & preprocessed game from the dataset 1769/5000
# Loaded & preprocessed game from the dataset 1776/5000
# Loaded & preprocessed game from the dataset 1778/5000
# Loaded & preprocessed game from the dataset 1779/5000
# Loaded & preprocessed game from the dataset 1780/5000
# Loaded & preprocessed game from the dataset 1782/5000
# Loaded & preprocessed game from the dataset 1783/5000
# Loaded & preprocessed game from the dataset 1786/5000
# Loaded & preprocessed game from the dataset 1788/5000
# Loaded & preprocessed game from the dataset 1794/5000
# Loaded & preprocessed game from the dataset 1795/5000
# Loaded & preprocessed game from the dataset 1798/5000
# Loaded & preprocessed game from the dataset 1800/5000
# Loaded & preprocessed game from the dataset 1802/5000
# Loaded & preprocessed game from the dataset 1811/5000
# Loaded & preprocessed game from the dataset 1817/5000
# Loaded & preprocessed game from the dataset 1820/5000
# Loaded & preprocessed game from the dataset 1825/5000
# Loaded & preprocessed game from the dataset 1826/5000
# Loaded & preprocessed game from the dataset 1827/5000
# Loaded & preprocessed game from the dataset 1830/5000
# Loaded & preprocessed game from the dataset 1832/5000
# Loaded & preprocessed game from the dataset 1838/5000
# Loaded & preprocessed game from the dataset 1839/5000
# Loaded & preprocessed game from the dataset 1841/5000
# Loaded & preprocessed game from the dataset 1846/5000
# Loaded & preprocessed game from the dataset 1857/5000
# Loaded & preprocessed game from the dataset 1859/5000
# Loaded & preprocessed game from the dataset 1865/5000
# Loaded & preprocessed game from the dataset 1868/5000
# Loaded & preprocessed game from the dataset 1872/5000
# Loaded & preprocessed game from the dataset 1873/5000
# Loaded & preprocessed game from the dataset 1874/5000
# Loaded & preprocessed game from the dataset 1876/5000
# Loaded & preprocessed game from the dataset 1878/5000
# Loaded & preprocessed game from the dataset 1880/5000
# Loaded & preprocessed game from the dataset 1886/5000
# Loaded & preprocessed game from the dataset 1887/5000
# Loaded & preprocessed game from the dataset 1899/5000
# Loaded & preprocessed game from the dataset 1903/5000
# Loaded & preprocessed game from the dataset 1906/5000
# Loaded & preprocessed game from the dataset 1907/5000
# Loaded & preprocessed game from the dataset 1910/5000
# Loaded & preprocessed game from the dataset 1913/5000
# Loaded & preprocessed game from the dataset 1917/5000
# Loaded & preprocessed game from the dataset 1920/5000
# Loaded & preprocessed game from the dataset 1921/5000
# Loaded & preprocessed game from the dataset 1924/5000
# Loaded & preprocessed game from the dataset 1928/5000
# Loaded & preprocessed game from the dataset 1930/5000
# Loaded & preprocessed game from the dataset 1935/5000
# Loaded & preprocessed game from the dataset 1942/5000
# Loaded & preprocessed game from the dataset 1943/5000
# Loaded & preprocessed game from the dataset 1944/5000
# Loaded & preprocessed game from the dataset 1945/5000
# Loaded & preprocessed game from the dataset 1947/5000
# Loaded & preprocessed game from the dataset 1952/5000
# Loaded & preprocessed game from the dataset 1954/5000
# Loaded & preprocessed game from the dataset 1955/5000
# Loaded & preprocessed game from the dataset 1960/5000
# Loaded & preprocessed game from the dataset 1961/5000
# Loaded & preprocessed game from the dataset 1962/5000
# Loaded & preprocessed game from the dataset 1964/5000
# Loaded & preprocessed game from the dataset 1968/5000
# Loaded & preprocessed game from the dataset 1977/5000
# Loaded & preprocessed game from the dataset 1978/5000
# Loaded & preprocessed game from the dataset 1982/5000
# Loaded & preprocessed game from the dataset 1984/5000
# Loaded & preprocessed game from the dataset 1989/5000
# Loaded & preprocessed game from the dataset 1993/5000
# Loaded & preprocessed game from the dataset 1995/5000
# Loaded & preprocessed game from the dataset 1996/5000
# Loaded & preprocessed game from the dataset 1998/5000
# Loaded & preprocessed game from the dataset 1999/5000
# Loaded & preprocessed game from the dataset 2002/5000
# Loaded & preprocessed game from the dataset 2005/5000
# Loaded & preprocessed game from the dataset 2011/5000
# Loaded & preprocessed game from the dataset 2016/5000
# Loaded & preprocessed game from the dataset 2024/5000
# Loaded & preprocessed game from the dataset 2031/5000
# Loaded & preprocessed game from the dataset 2035/5000
# Loaded & preprocessed game from the dataset 2039/5000
# Loaded & preprocessed game from the dataset 2040/5000
# Loaded & preprocessed game from the dataset 2043/5000
# Loaded & preprocessed game from the dataset 2046/5000
# Loaded & preprocessed game from the dataset 2047/5000
# Loaded & preprocessed game from the dataset 2048/5000
# Loaded & preprocessed game from the dataset 2050/5000
# Loaded & preprocessed game from the dataset 2051/5000
# Loaded & preprocessed game from the dataset 2055/5000
# Loaded & preprocessed game from the dataset 2061/5000
# Loaded & preprocessed game from the dataset 2063/5000
# Loaded & preprocessed game from the dataset 2069/5000
# Loaded & preprocessed game from the dataset 2072/5000
# Loaded & preprocessed game from the dataset 2076/5000
# Loaded & preprocessed game from the dataset 2078/5000
# Loaded & preprocessed game from the dataset 2082/5000
# Loaded & preprocessed game from the dataset 2083/5000
# Loaded & preprocessed game from the dataset 2089/5000
# Loaded & preprocessed game from the dataset 2091/5000
# Loaded & preprocessed game from the dataset 2096/5000
# Loaded & preprocessed game from the dataset 2098/5000
# Loaded & preprocessed game from the dataset 2102/5000
# Loaded & preprocessed game from the dataset 2105/5000
# Loaded & preprocessed game from the dataset 2113/5000
# Loaded & preprocessed game from the dataset 2119/5000
# Loaded & preprocessed game from the dataset 2121/5000
# Loaded & preprocessed game from the dataset 2123/5000
# Loaded & preprocessed game from the dataset 2124/5000
# Loaded & preprocessed game from the dataset 2133/5000
# Loaded & preprocessed game from the dataset 2136/5000
# Loaded & preprocessed game from the dataset 2139/5000
# Loaded & preprocessed game from the dataset 2141/5000
# Loaded & preprocessed game from the dataset 2143/5000
# Loaded & preprocessed game from the dataset 2149/5000
# Loaded & preprocessed game from the dataset 2150/5000
# Loaded & preprocessed game from the dataset 2153/5000
# Loaded & preprocessed game from the dataset 2156/5000
# Loaded & preprocessed game from the dataset 2157/5000
# Loaded & preprocessed game from the dataset 2158/5000
# Loaded & preprocessed game from the dataset 2167/5000
# Loaded & preprocessed game from the dataset 2168/5000
# Loaded & preprocessed game from the dataset 2169/5000
# Loaded & preprocessed game from the dataset 2170/5000
# Loaded & preprocessed game from the dataset 2171/5000
# Loaded & preprocessed game from the dataset 2176/5000
# Loaded & preprocessed game from the dataset 2183/5000
# Loaded & preprocessed game from the dataset 2191/5000
# Loaded & preprocessed game from the dataset 2193/5000
# Loaded & preprocessed game from the dataset 2194/5000
# Loaded & preprocessed game from the dataset 2197/5000
# Loaded & preprocessed game from the dataset 2198/5000
# Loaded & preprocessed game from the dataset 2199/5000
# Loaded & preprocessed game from the dataset 2206/5000
# Loaded & preprocessed game from the dataset 2211/5000
# Loaded & preprocessed game from the dataset 2216/5000
# Loaded & preprocessed game from the dataset 2218/5000
# Loaded & preprocessed game from the dataset 2223/5000
# Loaded & preprocessed game from the dataset 2228/5000
# Loaded & preprocessed game from the dataset 2233/5000
# Loaded & preprocessed game from the dataset 2234/5000
# Loaded & preprocessed game from the dataset 2235/5000
# Loaded & preprocessed game from the dataset 2236/5000
# Loaded & preprocessed game from the dataset 2243/5000
# Loaded & preprocessed game from the dataset 2244/5000
# Loaded & preprocessed game from the dataset 2248/5000
# Loaded & preprocessed game from the dataset 2249/5000
# Loaded & preprocessed game from the dataset 2250/5000
# Loaded & preprocessed game from the dataset 2253/5000
# Loaded & preprocessed game from the dataset 2258/5000
# Loaded & preprocessed game from the dataset 2260/5000
# Loaded & preprocessed game from the dataset 2263/5000
# Loaded & preprocessed game from the dataset 2264/5000
# Loaded & preprocessed game from the dataset 2268/5000
# Loaded & preprocessed game from the dataset 2269/5000
# Loaded & preprocessed game from the dataset 2276/5000
# Loaded & preprocessed game from the dataset 2278/5000
# Loaded & preprocessed game from the dataset 2281/5000
# Loaded & preprocessed game from the dataset 2284/5000
# Loaded & preprocessed game from the dataset 2290/5000
# Loaded & preprocessed game from the dataset 2295/5000
# Loaded & preprocessed game from the dataset 2298/5000
# Loaded & preprocessed game from the dataset 2300/5000
# Loaded & preprocessed game from the dataset 2303/5000
# Loaded & preprocessed game from the dataset 2306/5000
# Loaded & preprocessed game from the dataset 2308/5000
# Loaded & preprocessed game from the dataset 2309/5000
# Loaded & preprocessed game from the dataset 2311/5000
# Loaded & preprocessed game from the dataset 2316/5000
# Loaded & preprocessed game from the dataset 2318/5000
# Loaded & preprocessed game from the dataset 2327/5000
# Loaded & preprocessed game from the dataset 2328/5000
# Loaded & preprocessed game from the dataset 2333/5000
# Loaded & preprocessed game from the dataset 2340/5000
# Loaded & preprocessed game from the dataset 2345/5000
# Loaded & preprocessed game from the dataset 2348/5000
# Loaded & preprocessed game from the dataset 2349/5000
# Loaded & preprocessed game from the dataset 2351/5000
# Loaded & preprocessed game from the dataset 2354/5000
# Loaded & preprocessed game from the dataset 2359/5000
# Loaded & preprocessed game from the dataset 2367/5000
# Loaded & preprocessed game from the dataset 2369/5000
# Loaded & preprocessed game from the dataset 2375/5000
# Loaded & preprocessed game from the dataset 2379/5000
# Loaded & preprocessed game from the dataset 2384/5000
# Loaded & preprocessed game from the dataset 2386/5000
# Loaded & preprocessed game from the dataset 2388/5000
# Loaded & preprocessed game from the dataset 2389/5000
# Loaded & preprocessed game from the dataset 2391/5000
# Loaded & preprocessed game from the dataset 2392/5000
# Loaded & preprocessed game from the dataset 2400/5000
# Loaded & preprocessed game from the dataset 2401/5000
# Loaded & preprocessed game from the dataset 2403/5000
# Loaded & preprocessed game from the dataset 2408/5000
# Loaded & preprocessed game from the dataset 2410/5000
# Loaded & preprocessed game from the dataset 2413/5000
# Loaded & preprocessed game from the dataset 2419/5000
# Loaded & preprocessed game from the dataset 2420/5000
# Loaded & preprocessed game from the dataset 2422/5000
# Loaded & preprocessed game from the dataset 2423/5000
# Loaded & preprocessed game from the dataset 2424/5000
# Loaded & preprocessed game from the dataset 2428/5000
# Loaded & preprocessed game from the dataset 2429/5000
# Loaded & preprocessed game from the dataset 2440/5000
# Loaded & preprocessed game from the dataset 2444/5000
# Loaded & preprocessed game from the dataset 2445/5000
# Loaded & preprocessed game from the dataset 2450/5000
# Loaded & preprocessed game from the dataset 2453/5000
# Loaded & preprocessed game from the dataset 2463/5000
# Loaded & preprocessed game from the dataset 2464/5000
# Loaded & preprocessed game from the dataset 2467/5000
# Loaded & preprocessed game from the dataset 2469/5000
# Loaded & preprocessed game from the dataset 2470/5000
# Loaded & preprocessed game from the dataset 2471/5000
# Loaded & preprocessed game from the dataset 2472/5000
# Loaded & preprocessed game from the dataset 2477/5000
# Loaded & preprocessed game from the dataset 2478/5000
# Loaded & preprocessed game from the dataset 2484/5000
# Loaded & preprocessed game from the dataset 2488/5000
# Loaded & preprocessed game from the dataset 2497/5000
# Loaded & preprocessed game from the dataset 2498/5000
# Loaded & preprocessed game from the dataset 2507/5000
# Loaded & preprocessed game from the dataset 2511/5000
# Loaded & preprocessed game from the dataset 2513/5000
# Loaded & preprocessed game from the dataset 2514/5000
# Loaded & preprocessed game from the dataset 2522/5000
# Loaded & preprocessed game from the dataset 2524/5000
# Loaded & preprocessed game from the dataset 2532/5000
# Loaded & preprocessed game from the dataset 2535/5000
# Loaded & preprocessed game from the dataset 2541/5000
# Loaded & preprocessed game from the dataset 2550/5000
# Loaded & preprocessed game from the dataset 2553/5000
# Loaded & preprocessed game from the dataset 2557/5000
# Loaded & preprocessed game from the dataset 2572/5000
# Loaded & preprocessed game from the dataset 2574/5000
# Loaded & preprocessed game from the dataset 2575/5000
# Loaded & preprocessed game from the dataset 2578/5000
# Loaded & preprocessed game from the dataset 2579/5000
# Loaded & preprocessed game from the dataset 2586/5000
# Loaded & preprocessed game from the dataset 2587/5000
# Loaded & preprocessed game from the dataset 2592/5000
# Loaded & preprocessed game from the dataset 2607/5000
# Loaded & preprocessed game from the dataset 2609/5000
# Loaded & preprocessed game from the dataset 2618/5000
# Loaded & preprocessed game from the dataset 2624/5000
# Loaded & preprocessed game from the dataset 2626/5000
# Loaded & preprocessed game from the dataset 2627/5000
# Loaded & preprocessed game from the dataset 2629/5000
# Loaded & preprocessed game from the dataset 2632/5000
# Loaded & preprocessed game from the dataset 2635/5000
# Loaded & preprocessed game from the dataset 2637/5000
# Loaded & preprocessed game from the dataset 2643/5000
# Loaded & preprocessed game from the dataset 2648/5000
# Loaded & preprocessed game from the dataset 2653/5000
# Loaded & preprocessed game from the dataset 2655/5000
# Loaded & preprocessed game from the dataset 2662/5000
# Loaded & preprocessed game from the dataset 2674/5000
# Loaded & preprocessed game from the dataset 2675/5000
# Loaded & preprocessed game from the dataset 2676/5000
# Loaded & preprocessed game from the dataset 2677/5000
# Loaded & preprocessed game from the dataset 2680/5000
# Loaded & preprocessed game from the dataset 2681/5000
# Loaded & preprocessed game from the dataset 2683/5000
# Loaded & preprocessed game from the dataset 2687/5000
# Loaded & preprocessed game from the dataset 2690/5000
# Loaded & preprocessed game from the dataset 2691/5000
# Loaded & preprocessed game from the dataset 2692/5000
# Loaded & preprocessed game from the dataset 2695/5000
# Loaded & preprocessed game from the dataset 2696/5000
# Loaded & preprocessed game from the dataset 2705/5000
# Loaded & preprocessed game from the dataset 2706/5000
# Loaded & preprocessed game from the dataset 2707/5000
# Loaded & preprocessed game from the dataset 2710/5000
# Loaded & preprocessed game from the dataset 2713/5000
# Loaded & preprocessed game from the dataset 2714/5000
# Loaded & preprocessed game from the dataset 2721/5000
# Loaded & preprocessed game from the dataset 2724/5000
# Loaded & preprocessed game from the dataset 2726/5000
# Loaded & preprocessed game from the dataset 2730/5000
# Loaded & preprocessed game from the dataset 2734/5000
# Loaded & preprocessed game from the dataset 2735/5000
# Loaded & preprocessed game from the dataset 2740/5000
# Loaded & preprocessed game from the dataset 2742/5000
# Loaded & preprocessed game from the dataset 2744/5000
# Loaded & preprocessed game from the dataset 2745/5000
# Loaded & preprocessed game from the dataset 2747/5000
# Loaded & preprocessed game from the dataset 2748/5000
# Loaded & preprocessed game from the dataset 2751/5000
# Loaded & preprocessed game from the dataset 2753/5000
# Loaded & preprocessed game from the dataset 2754/5000
# Loaded & preprocessed game from the dataset 2757/5000
# Loaded & preprocessed game from the dataset 2758/5000
# Loaded & preprocessed game from the dataset 2760/5000
# Loaded & preprocessed game from the dataset 2761/5000
# Loaded & preprocessed game from the dataset 2762/5000
# Loaded & preprocessed game from the dataset 2768/5000
# Loaded & preprocessed game from the dataset 2769/5000
# Loaded & preprocessed game from the dataset 2772/5000
# Loaded & preprocessed game from the dataset 2777/5000
# Loaded & preprocessed game from the dataset 2780/5000
# Loaded & preprocessed game from the dataset 2781/5000
# Loaded & preprocessed game from the dataset 2791/5000
# Loaded & preprocessed game from the dataset 2793/5000
# Loaded & preprocessed game from the dataset 2797/5000
# Loaded & preprocessed game from the dataset 2798/5000
# Loaded & preprocessed game from the dataset 2799/5000
# Loaded & preprocessed game from the dataset 2800/5000
# Loaded & preprocessed game from the dataset 2802/5000
# Loaded & preprocessed game from the dataset 2805/5000
# Loaded & preprocessed game from the dataset 2806/5000
# Loaded & preprocessed game from the dataset 2808/5000
# Loaded & preprocessed game from the dataset 2817/5000
# Loaded & preprocessed game from the dataset 2818/5000
# Loaded & preprocessed game from the dataset 2819/5000
# Loaded & preprocessed game from the dataset 2822/5000
# Loaded & preprocessed game from the dataset 2823/5000
# Loaded & preprocessed game from the dataset 2824/5000
# Loaded & preprocessed game from the dataset 2834/5000
# Loaded & preprocessed game from the dataset 2835/5000
# Loaded & preprocessed game from the dataset 2836/5000
# Loaded & preprocessed game from the dataset 2840/5000
# Loaded & preprocessed game from the dataset 2850/5000
# Loaded & preprocessed game from the dataset 2854/5000
# Loaded & preprocessed game from the dataset 2856/5000
# Loaded & preprocessed game from the dataset 2860/5000
# Loaded & preprocessed game from the dataset 2863/5000
# Loaded & preprocessed game from the dataset 2869/5000
# Loaded & preprocessed game from the dataset 2870/5000
# Loaded & preprocessed game from the dataset 2872/5000
# Loaded & preprocessed game from the dataset 2873/5000
# Loaded & preprocessed game from the dataset 2877/5000
# Loaded & preprocessed game from the dataset 2882/5000
# ...
# Loaded & preprocessed game from the dataset 4185/5000
# Loaded & preprocessed game from the dataset 4187/5000
# Loaded & preprocessed game from the dataset 4188/5000
# Loaded & preprocessed game from the dataset 4192/5000
# Loaded & preprocessed game from the dataset 4193/5000
# Loaded & preprocessed game from the dataset 4194/5000
# Loaded & preprocessed game from the dataset 4195/5000
# Loaded & preprocessed game from the dataset 4197/5000
# Loaded & preprocessed game from the dataset 4198/5000
# Loaded & preprocessed game from the dataset 4204/5000
# Loaded & preprocessed game from the dataset 4205/5000
# Loaded & preprocessed game from the dataset 4209/5000
# Loaded & preprocessed game from the dataset 4210/5000
# Loaded & preprocessed game from the dataset 4213/5000
# Loaded & preprocessed game from the dataset 4216/5000
# Loaded & preprocessed game from the dataset 4217/5000
# Loaded & preprocessed game from the dataset 4218/5000
# Loaded & preprocessed game from the dataset 4219/5000
# Loaded & preprocessed game from the dataset 4220/5000
# Loaded & preprocessed game from the dataset 4221/5000
# Loaded & preprocessed game from the dataset 4225/5000
# Loaded & preprocessed game from the dataset 4226/5000
# Loaded & preprocessed game from the dataset 4227/5000
# Loaded & preprocessed game from the dataset 4228/5000
# Loaded & preprocessed game from the dataset 4232/5000
# Loaded & preprocessed game from the dataset 4233/5000
# Loaded & preprocessed game from the dataset 4234/5000
# Loaded & preprocessed game from the dataset 4236/5000
# Loaded & preprocessed game from the dataset 4237/5000
# Loaded & preprocessed game from the dataset 4241/5000
# Loaded & preprocessed game from the dataset 4243/5000
# Loaded & preprocessed game from the dataset 4250/5000
# Loaded & preprocessed game from the dataset 4252/5000
# Loaded & preprocessed game from the dataset 4255/5000
# Loaded & preprocessed game from the dataset 4256/5000
# Loaded & preprocessed game from the dataset 4260/5000
# Loaded & preprocessed game from the dataset 4263/5000
# Loaded & preprocessed game from the dataset 4265/5000
# Loaded & preprocessed game from the dataset 4268/5000
# Loaded & preprocessed game from the dataset 4270/5000
# Loaded & preprocessed game from the dataset 4274/5000
# Loaded & preprocessed game from the dataset 4276/5000
# Loaded & preprocessed game from the dataset 4277/5000
# Loaded & preprocessed game from the dataset 4282/5000
# Loaded & preprocessed game from the dataset 4285/5000
# Loaded & preprocessed game from the dataset 4303/5000
# Loaded & preprocessed game from the dataset 4304/5000
# Loaded & preprocessed game from the dataset 4305/5000
# Loaded & preprocessed game from the dataset 4306/5000
# Loaded & preprocessed game from the dataset 4313/5000
# Loaded & preprocessed game from the dataset 4314/5000
# Loaded & preprocessed game from the dataset 4316/5000
# Loaded & preprocessed game from the dataset 4318/5000
# Loaded & preprocessed game from the dataset 4325/5000
# Loaded & preprocessed game from the dataset 4327/5000
# Loaded & preprocessed game from the dataset 4331/5000
# Loaded & preprocessed game from the dataset 4333/5000
# Loaded & preprocessed game from the dataset 4335/5000
# Loaded & preprocessed game from the dataset 4337/5000
# Loaded & preprocessed game from the dataset 4342/5000
# Loaded & preprocessed game from the dataset 4346/5000
# Loaded & preprocessed game from the dataset 4351/5000
# Loaded & preprocessed game from the dataset 4354/5000
# Loaded & preprocessed game from the dataset 4356/5000
# Loaded & preprocessed game from the dataset 4359/5000
# Loaded & preprocessed game from the dataset 4360/5000
# Loaded & preprocessed game from the dataset 4364/5000
# Loaded & preprocessed game from the dataset 4365/5000
# Loaded & preprocessed game from the dataset 4366/5000
# Loaded & preprocessed game from the dataset 4370/5000
# Loaded & preprocessed game from the dataset 4371/5000
# Loaded & preprocessed game from the dataset 4374/5000
# Loaded & preprocessed game from the dataset 4375/5000
# Loaded & preprocessed game from the dataset 4379/5000
# Loaded & preprocessed game from the dataset 4380/5000
# Loaded & preprocessed game from the dataset 4381/5000
# Loaded & preprocessed game from the dataset 4385/5000
# Loaded & preprocessed game from the dataset 4386/5000
# Loaded & preprocessed game from the dataset 4390/5000
# Loaded & preprocessed game from the dataset 4399/5000
# Loaded & preprocessed game from the dataset 4403/5000
# Loaded & preprocessed game from the dataset 4405/5000
# Loaded & preprocessed game from the dataset 4406/5000
# Loaded & preprocessed game from the dataset 4408/5000
# Loaded & preprocessed game from the dataset 4410/5000
# Loaded & preprocessed game from the dataset 4412/5000
# Loaded & preprocessed game from the dataset 4414/5000
# Loaded & preprocessed game from the dataset 4418/5000
# Loaded & preprocessed game from the dataset 4419/5000
# Loaded & preprocessed game from the dataset 4421/5000
# Loaded & preprocessed game from the dataset 4426/5000
# Loaded & preprocessed game from the dataset 4428/5000
# Loaded & preprocessed game from the dataset 4432/5000
# Loaded & preprocessed game from the dataset 4433/5000
# Loaded & preprocessed game from the dataset 4434/5000
# Loaded & preprocessed game from the dataset 4435/5000
# Loaded & preprocessed game from the dataset 4439/5000
# Loaded & preprocessed game from the dataset 4444/5000
# Loaded & preprocessed game from the dataset 4445/5000
# Loaded & preprocessed game from the dataset 4453/5000
# Loaded & preprocessed game from the dataset 4458/5000
# Loaded & preprocessed game from the dataset 4467/5000
# Loaded & preprocessed game from the dataset 4468/5000
# Loaded & preprocessed game from the dataset 4471/5000
# Loaded & preprocessed game from the dataset 4472/5000
# Loaded & preprocessed game from the dataset 4482/5000
# Loaded & preprocessed game from the dataset 4484/5000
# Loaded & preprocessed game from the dataset 4485/5000
# Loaded & preprocessed game from the dataset 4487/5000
# Loaded & preprocessed game from the dataset 4492/5000
# Loaded & preprocessed game from the dataset 4496/5000
# Loaded & preprocessed game from the dataset 4508/5000
# Loaded & preprocessed game from the dataset 4511/5000
# Loaded & preprocessed game from the dataset 4513/5000
# Loaded & preprocessed game from the dataset 4522/5000
# Loaded & preprocessed game from the dataset 4523/5000
# Loaded & preprocessed game from the dataset 4528/5000
# Loaded & preprocessed game from the dataset 4529/5000
# Loaded & preprocessed game from the dataset 4537/5000
# Loaded & preprocessed game from the dataset 4540/5000
# Loaded & preprocessed game from the dataset 4541/5000
# Loaded & preprocessed game from the dataset 4546/5000
# Loaded & preprocessed game from the dataset 4551/5000
# Loaded & preprocessed game from the dataset 4553/5000
# Loaded & preprocessed game from the dataset 4554/5000
# Loaded & preprocessed game from the dataset 4555/5000
# Loaded & preprocessed game from the dataset 4556/5000
# Loaded & preprocessed game from the dataset 4558/5000
# Loaded & preprocessed game from the dataset 4560/5000
# Loaded & preprocessed game from the dataset 4565/5000
# Loaded & preprocessed game from the dataset 4571/5000
# Loaded & preprocessed game from the dataset 4573/5000
# Loaded & preprocessed game from the dataset 4575/5000
# Loaded & preprocessed game from the dataset 4577/5000
# Loaded & preprocessed game from the dataset 4579/5000
# Loaded & preprocessed game from the dataset 4581/5000
# Loaded & preprocessed game from the dataset 4584/5000
# Loaded & preprocessed game from the dataset 4585/5000
# Loaded & preprocessed game from the dataset 4591/5000
# Loaded & preprocessed game from the dataset 4592/5000
# Loaded & preprocessed game from the dataset 4597/5000
# Loaded & preprocessed game from the dataset 4603/5000
# Loaded & preprocessed game from the dataset 4611/5000
# Loaded & preprocessed game from the dataset 4612/5000
# Loaded & preprocessed game from the dataset 4615/5000
# Loaded & preprocessed game from the dataset 4617/5000
# Loaded & preprocessed game from the dataset 4619/5000
# Loaded & preprocessed game from the dataset 4624/5000
# Loaded & preprocessed game from the dataset 4631/5000
# Loaded & preprocessed game from the dataset 4634/5000
# Loaded & preprocessed game from the dataset 4635/5000
# Loaded & preprocessed game from the dataset 4636/5000
# Loaded & preprocessed game from the dataset 4637/5000
# Loaded & preprocessed game from the dataset 4638/5000
# Loaded & preprocessed game from the dataset 4639/5000
# Loaded & preprocessed game from the dataset 4641/5000
# Loaded & preprocessed game from the dataset 4645/5000
# Loaded & preprocessed game from the dataset 4647/5000
# Loaded & preprocessed game from the dataset 4652/5000
# Loaded & preprocessed game from the dataset 4656/5000
# Loaded & preprocessed game from the dataset 4657/5000
# Loaded & preprocessed game from the dataset 4660/5000
# Loaded & preprocessed game from the dataset 4661/5000
# Loaded & preprocessed game from the dataset 4662/5000
# Loaded & preprocessed game from the dataset 4669/5000
# Loaded & preprocessed game from the dataset 4675/5000
# Loaded & preprocessed game from the dataset 4677/5000
# Loaded & preprocessed game from the dataset 4680/5000
# Loaded & preprocessed game from the dataset 4686/5000
# Loaded & preprocessed game from the dataset 4689/5000
# Loaded & preprocessed game from the dataset 4693/5000
# Loaded & preprocessed game from the dataset 4696/5000
# Loaded & preprocessed game from the dataset 4699/5000
# Loaded & preprocessed game from the dataset 4703/5000
# Loaded & preprocessed game from the dataset 4707/5000
# Loaded & preprocessed game from the dataset 4712/5000
# Loaded & preprocessed game from the dataset 4715/5000
# Loaded & preprocessed game from the dataset 4717/5000
# Loaded & preprocessed game from the dataset 4719/5000
# Loaded & preprocessed game from the dataset 4721/5000
# Loaded & preprocessed game from the dataset 4724/5000
# Loaded & preprocessed game from the dataset 4726/5000
# Loaded & preprocessed game from the dataset 4727/5000
# Loaded & preprocessed game from the dataset 4730/5000
# Loaded & preprocessed game from the dataset 4731/5000
# Loaded & preprocessed game from the dataset 4732/5000
# Loaded & preprocessed game from the dataset 4735/5000
# Loaded & preprocessed game from the dataset 4741/5000
# Loaded & preprocessed game from the dataset 4744/5000
# Loaded & preprocessed game from the dataset 4754/5000
# Loaded & preprocessed game from the dataset 4755/5000
# Loaded & preprocessed game from the dataset 4756/5000
# Loaded & preprocessed game from the dataset 4757/5000
# Loaded & preprocessed game from the dataset 4764/5000
# Loaded & preprocessed game from the dataset 4766/5000
# Loaded & preprocessed game from the dataset 4773/5000
# Loaded & preprocessed game from the dataset 4782/5000
# Loaded & preprocessed game from the dataset 4786/5000
# Loaded & preprocessed game from the dataset 4794/5000
# Loaded & preprocessed game from the dataset 4795/5000
# Loaded & preprocessed game from the dataset 4796/5000
# Loaded & preprocessed game from the dataset 4801/5000
# Loaded & preprocessed game from the dataset 4802/5000
# Loaded & preprocessed game from the dataset 4807/5000
# Loaded & preprocessed game from the dataset 4812/5000
# Loaded & preprocessed game from the dataset 4814/5000
# Loaded & preprocessed game from the dataset 4815/5000
# Loaded & preprocessed game from the dataset 4816/5000
# Loaded & preprocessed game from the dataset 4817/5000
# Loaded & preprocessed game from the dataset 4819/5000
# Loaded & preprocessed game from the dataset 4823/5000
# Loaded & preprocessed game from the dataset 4824/5000
# Loaded & preprocessed game from the dataset 4826/5000
# Loaded & preprocessed game from the dataset 4828/5000
# Loaded & preprocessed game from the dataset 4829/5000
# Loaded & preprocessed game from the dataset 4841/5000
# Loaded & preprocessed game from the dataset 4850/5000
# Loaded & preprocessed game from the dataset 4854/5000
# Loaded & preprocessed game from the dataset 4860/5000
# Loaded & preprocessed game from the dataset 4861/5000
# Loaded & preprocessed game from the dataset 4863/5000
# Loaded & preprocessed game from the dataset 4864/5000
# Loaded & preprocessed game from the dataset 4865/5000
# Loaded & preprocessed game from the dataset 4866/5000
# Loaded & preprocessed game from the dataset 4868/5000
# Loaded & preprocessed game from the dataset 4869/5000
# Loaded & preprocessed game from the dataset 4870/5000
# Loaded & preprocessed game from the dataset 4872/5000
# Loaded & preprocessed game from the dataset 4877/5000
# Loaded & preprocessed game from the dataset 4879/5000
# Loaded & preprocessed game from the dataset 4880/5000
# Loaded & preprocessed game from the dataset 4887/5000
# Loaded & preprocessed game from the dataset 4892/5000
# Loaded & preprocessed game from the dataset 4893/5000
# Loaded & preprocessed game from the dataset 4894/5000
# Loaded & preprocessed game from the dataset 4896/5000
# Loaded & preprocessed game from the dataset 4902/5000
# Loaded & preprocessed game from the dataset 4906/5000
# Loaded & preprocessed game from the dataset 4907/5000
# Loaded & preprocessed game from the dataset 4909/5000
# Loaded & preprocessed game from the dataset 4911/5000
# Loaded & preprocessed game from the dataset 4917/5000
# Loaded & preprocessed game from the dataset 4920/5000
# Loaded & preprocessed game from the dataset 4921/5000
# Loaded & preprocessed game from the dataset 4924/5000
# Loaded & preprocessed game from the dataset 4925/5000
# Loaded & preprocessed game from the dataset 4927/5000
# Loaded & preprocessed game from the dataset 4928/5000
# Loaded & preprocessed game from the dataset 4931/5000
# Loaded & preprocessed game from the dataset 4933/5000
# Loaded & preprocessed game from the dataset 4938/5000
# Loaded & preprocessed game from the dataset 4941/5000
# Loaded & preprocessed game from the dataset 4942/5000
# Loaded & preprocessed game from the dataset 4947/5000
# Loaded & preprocessed game from the dataset 4948/5000
# Loaded & preprocessed game from the dataset 4954/5000
# Loaded & preprocessed game from the dataset 4960/5000
# Loaded & preprocessed game from the dataset 4962/5000
# Loaded & preprocessed game from the dataset 4963/5000
# Loaded & preprocessed game from the dataset 4964/5000
# Loaded & preprocessed game from the dataset 4968/5000
# Loaded & preprocessed game from the dataset 4969/5000
# Loaded & preprocessed game from the dataset 4973/5000
# Loaded & preprocessed game from the dataset 4976/5000
# Loaded & preprocessed game from the dataset 4977/5000
# Loaded & preprocessed game from the dataset 4978/5000
# Loaded & preprocessed game from the dataset 4981/5000
# Loaded & preprocessed game from the dataset 4983/5000
# Loaded & preprocessed game from the dataset 4987/5000
# Loaded & preprocessed game from the dataset 4991/5000
# Loaded & preprocessed game from the dataset 4992/5000
# Loaded & preprocessed game from the dataset 4994/5000
# Loaded & preprocessed game from the dataset 4996/5000
# Loaded & preprocessed game from the dataset 4997/5000
# Loaded & preprocessed game from the dataset 4999/5000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 20
#      18 for dataset_batch in range(0, training_limit, dataset_batch_step):
#      19   print(f"Processing dataset batch: {dataset_batch} / {training_limit}")
# ---> 20   ps_dataloader, ms_dataloaders = load_dataloaders(original_headers, 5000, dataset_batch)
#      22   print("Training piece selector model")
#      23   train(ps_dataloader, piece_selector, device)
#
# Cell In[9], line 47, in load_dataloaders(original_headers, limit, offset)
#      42     index = PIECE_TYPES[piece_type]
#      43     ms_X, ms_y = zip(*move_selection[index])
#      44     ms_dataloaders.append(
#      45         DataLoader(
#      46             TensorDataset(
# ---> 47                 torch.tensor(ms_X, dtype=torch.float32),
#      48                 torch.tensor(ms_y, dtype=torch.long),
#      49             ),
#      50             batch_size=BATCH_SIZE,
#      51             shuffle=SHUFFLE,
#      52         )
#      53     )
#      55 return ps_dataloader, ms_dataloaders
#
# KeyboardInterrupt:
